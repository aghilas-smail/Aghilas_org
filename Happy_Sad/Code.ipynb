# %% [markdown]
# Classification HAPPY and SAD People using a CNN Model.

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (489.8 MB)
# Collecting absl-py>=1.0.0
#   Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Using cached protobuf-4.24.4-cp37-abi3-manylinux2014_x86_64.whl (311 kB)
# Collecting wrapt<1.15,>=1.11.0
#   Using cached wrapt-1.14.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (77 kB)
# Requirement already satisfied: six>=1.12.0 in ./myenv/lib/python3.10/site-packages (from tensorflow) (1.16.0)
# Collecting h5py>=2.9.0
#   Using cached h5py-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Collecting grpcio<2.0,>=1.24.3
#   Using cached grpcio-1.59.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Collecting tensorboard<2.15,>=2.14
#   Using cached tensorboard-2.14.1-py3-none-any.whl (5.5 MB)
# Collecting libclang>=13.0.0
#   Using cached libclang-16.0.6-py2.py3-none-manylinux2010_x86_64.whl (22.9 MB)
# Collecting keras<2.15,>=2.14.0
#   Using cached keras-2.14.0-py3-none-any.whl (1.7 MB)
# Requirement already satisfied: packaging in ./myenv/lib/python3.10/site-packages (from tensorflow) (23.2)
# Collecting numpy>=1.23.5
#   Using cached numpy-1.26.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Using cached tensorflow_io_gcs_filesystem-0.34.0-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
# Collecting astunparse>=1.6.0
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting flatbuffers>=23.5.26
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Collecting typing-extensions>=3.6.6
#   Using cached typing_extensions-4.8.0-py3-none-any.whl (31 kB)
# Collecting termcolor>=1.1.0
#   Using cached termcolor-2.3.0-py3-none-any.whl (6.9 kB)
# Collecting tensorflow-estimator<2.15,>=2.14.0
#   Using cached tensorflow_estimator-2.14.0-py2.py3-none-any.whl (440 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1
#   Using cached gast-0.5.4-py3-none-any.whl (19 kB)
# Requirement already satisfied: setuptools in ./myenv/lib/python3.10/site-packages (from tensorflow) (59.6.0)
# Collecting ml-dtypes==0.2.0
#   Using cached ml_dtypes-0.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Collecting wheel<1.0,>=0.23.0
#   Downloading wheel-0.41.2-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 KB 455.0 kB/s eta 0:00:0031m1.7 MB/s eta 0:00:01
# Collecting markdown>=2.6.8
#   Using cached Markdown-3.5-py3-none-any.whl (101 kB)
# Collecting werkzeug>=1.0.1
#   Using cached werkzeug-3.0.0-py3-none-any.whl (226 kB)
# Collecting google-auth-oauthlib<1.1,>=0.5
#   Using cached google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting requests<3,>=2.21.0
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Using cached tensorboard_data_server-0.7.1-py3-none-manylinux2014_x86_64.whl (6.6 MB)
# Collecting google-auth<3,>=1.6.3
#   Using cached google_auth-2.23.3-py2.py3-none-any.whl (182 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Using cached cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
# Collecting requests-oauthlib>=0.7.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (138 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.7.22-py3-none-any.whl (158 kB)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.6-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.8/123.8 KB 1.5 MB/s eta 0:00:00m eta 0:00:01
# Collecting MarkupSafe>=2.1.1
#   Using cached MarkupSafe-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting pyasn1<0.6.0,>=0.4.6
#   Using cached pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 KB 2.0 MB/s eta 0:00:0031m10.7 MB/s eta 0:00:01
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, urllib3, typing-extensions, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, pyasn1, protobuf, oauthlib, numpy, MarkupSafe, markdown, keras, idna, grpcio, google-pasta, gast, charset-normalizer, certifi, cachetools, absl-py, werkzeug, rsa, requests, pyasn1-modules, opt-einsum, ml-dtypes, h5py, astunparse, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow
# Successfully installed MarkupSafe-2.1.3 absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.1 certifi-2023.7.22 charset-normalizer-3.3.0 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.23.3 google-auth-oauthlib-1.0.0 google-pasta-0.2.0 grpcio-1.59.0 h5py-3.10.0 idna-3.4 keras-2.14.0 libclang-16.0.6 markdown-3.5 ml-dtypes-0.2.0 numpy-1.26.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.24.4 pyasn1-0.5.0 pyasn1-modules-0.3.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.14.1 tensorboard-data-server-0.7.1 tensorflow-2.14.0 tensorflow-estimator-2.14.0 tensorflow-io-gcs-filesystem-0.34.0 termcolor-2.3.0 typing-extensions-4.8.0 urllib3-2.0.6 werkzeug-3.0.0 wheel-0.41.2 wrapt-1.14.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Make sure you have already installed these libraries.
#!pip install tensorflow tensorflow gpu opencv python matplotlib

# %%
import tensorflow as tf

# %%
# !pip list all
# Out:
# Package                      Version
# ---------------------------- ----------------
# absl-py                      2.0.0
# anyio                        4.0.0
# apturl                       0.5.2
# argon2-cffi                  23.1.0
# argon2-cffi-bindings         21.2.0
# arrow                        1.3.0
# asttokens                    2.4.0
# astunparse                   1.6.3
# async-lru                    2.0.4
# attrs                        23.1.0
# Babel                        2.13.0
# backcall                     0.2.0
# beautifulsoup4               4.12.2
# bleach                       6.1.0
# blinker                      1.4
# cachetools                   5.3.1
# catfish                      4.16.3
# certifi                      2023.7.22
# cffi                         1.15.0
# chardet                      4.0.0
# charset-normalizer           3.3.0
# click                        8.0.3
# colorama                     0.4.4
# comm                         0.1.4
# command-not-found            0.3
# contourpy                    1.1.1
# cryptography                 3.4.8
# cupshelpers                  1.0
# cycler                       0.12.1
# dbus-python                  1.2.18
# debugpy                      1.8.0
# decorator                    5.1.1
# defer                        1.0.6
# defusedxml                   0.7.1
# distro                       1.7.0
# distro-info                  1.1+ubuntu0.1
# exceptiongroup               1.1.3
# executing                    2.0.0
# fastjsonschema               2.18.1
# filelock                     3.12.4
# flatbuffers                  23.5.26
# fonttools                    4.43.1
# fqdn                         1.5.1
# fsspec                       2023.9.2
# gast                         0.5.4
# google-auth                  2.23.3
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.59.0
# h5py                         3.10.0
# httplib2                     0.20.2
# idna                         3.4
# importlib-metadata           4.6.4
# ipykernel                    6.25.2
# ipython                      8.16.1
# ipython-genutils             0.2.0
# ipywidgets                   8.1.1
# isoduration                  20.11.0
# jedi                         0.19.1
# jeepney                      0.7.1
# Jinja2                       3.1.2
# joblib                       1.3.2
# json5                        0.9.14
# jsonpointer                  2.4
# jsonschema                   4.19.1
# jsonschema-specifications    2023.7.1
# jupyter                      1.0.0
# jupyter_client               8.3.1
# jupyter-console              6.6.3
# jupyter_core                 5.3.2
# jupyter-events               0.7.0
# jupyter-lsp                  2.2.0
# jupyter_server               2.7.3
# jupyter_server_terminals     0.4.4
# jupyterlab                   4.0.6
# jupyterlab-pygments          0.2.2
# jupyterlab_server            2.25.0
# jupyterlab-widgets           3.0.9
# keras                        2.14.0
# keyring                      23.5.0
# kiwisolver                   1.4.5
# language-selector            0.1
# launchpadlib                 1.10.16
# lazr.restfulclient           0.14.4
# lazr.uri                     1.0.6
# libclang                     16.0.6
# lightdm-gtk-greeter-settings 1.2.2
# Mako                         1.1.3
# Markdown                     3.5
# MarkupSafe                   2.1.3
# matplotlib                   3.8.0
# matplotlib-inline            0.1.6
# menulibre                    2.2.2
# mistune                      3.0.2
# ml-dtypes                    0.2.0
# more-itertools               8.10.0
# mpmath                       1.3.0
# mugshot                      0.4.3
# nbclient                     0.8.0
# nbconvert                    7.9.2
# nbformat                     5.9.2
# nest-asyncio                 1.5.8
# netifaces                    0.11.0
# networkx                     3.1
# notebook                     7.0.4
# notebook_shim                0.2.3
# numpy                        1.26.0
# nvidia-cublas-cu12           12.1.3.1
# nvidia-cuda-cupti-cu12       12.1.105
# nvidia-cuda-nvrtc-cu12       12.1.105
# nvidia-cuda-runtime-cu12     12.1.105
# nvidia-cudnn-cu12            8.9.2.26
# nvidia-cufft-cu12            11.0.2.54
# nvidia-curand-cu12           10.3.2.106
# nvidia-cusolver-cu12         11.4.5.107
# nvidia-cusparse-cu12         12.1.0.106
# nvidia-nccl-cu12             2.18.1
# nvidia-nvjitlink-cu12        12.2.140
# nvidia-nvtx-cu12             12.1.105
# oauthlib                     3.2.0
# olefile                      0.46
# onboard                      1.4.1
# opencv-python                4.8.1.78
# opt-einsum                   3.3.0
# overrides                    7.4.0
# packaging                    23.2
# pandas                       2.1.1
# pandocfilters                1.5.0
# parso                        0.8.3
# pexpect                      4.8.0
# pickleshare                  0.7.5
# Pillow                       9.0.1
# pip                          22.0.2
# platformdirs                 3.11.0
# ply                          3.11
# prometheus-client            0.17.1
# prompt-toolkit               3.0.39
# protobuf                     4.24.4
# psutil                       5.9.0
# ptyprocess                   0.7.0
# pure-eval                    0.2.2
# pyasn1                       0.5.0
# pyasn1-modules               0.3.0
# pycairo                      1.20.1
# pycparser                    2.21
# pycups                       2.0.1
# Pygments                     2.16.1
# PyGObject                    3.42.1
# PyJWT                        2.3.0
# pyparsing                    2.4.7
# python-apt                   2.4.0+ubuntu2
# python-dateutil              2.8.2
# python-debian                0.1.43+ubuntu1.1
# python-json-logger           2.0.7
# pytz                         2023.3.post1
# PyYAML                       5.4.1
# pyzmq                        25.1.1
# qtconsole                    5.4.4
# QtPy                         2.4.0
# referencing                  0.30.2
# reportlab                    3.6.8
# requests                     2.31.0
# requests-oauthlib            1.3.1
# rfc3339-validator            0.1.4
# rfc3986-validator            0.1.1
# rpds-py                      0.10.4
# rsa                          4.9
# scikit-learn                 1.3.1
# scipy                        1.11.3
# SecretStorage                3.3.1
# Send2Trash                   1.8.2
# setuptools                   59.6.0
# sgt-launcher                 0.2.7
# six                          1.16.0
# sniffio                      1.3.0
# soupsieve                    2.5
# stack-data                   0.6.3
# sympy                        1.12
# systemd-python               234
# tensorboard                  2.14.1
# tensorboard-data-server      0.7.1
# tensorflow                   2.14.0
# tensorflow-estimator         2.14.0
# tensorflow-io-gcs-filesystem 0.34.0
# termcolor                    2.3.0
# terminado                    0.17.1
# threadpoolctl                3.2.0
# tinycss2                     1.2.1
# tomli                        2.0.1
# torch                        2.1.0
# tornado                      6.3.3
# traitlets                    5.11.2
# triton                       2.1.0
# types-python-dateutil        2.8.19.14
# typing_extensions            4.8.0
# tzdata                       2023.3
# ubuntu-advantage-tools       8001
# ubuntu-drivers-common        0.0.0
# ufw                          0.36.1
# unattended-upgrades          0.1
# uri-template                 1.3.0
# urllib3                      1.26.5
# wadllib                      1.3.6
# wcwidth                      0.2.8
# webcolors                    1.13
# webencodings                 0.5.1
# websocket-client             1.6.4
# Werkzeug                     3.0.0
# wheel                        0.37.1
# widgetsnbextension           4.0.9
# wrapt                        1.14.1
# xcffib                       0.11.1
# xkit                         0.0.0
# zipp                         1.0.0

# %%
import os
