# %%
import speech_recognition as sr

def transcribe_live_audio():
    recognizer = sr.Recognizer()
    microphone = sr.Microphone()

    print("Réglage du bruit ambiant...")
    with microphone as source:
        recognizer.adjust_for_ambient_noise(source)

    print("Transcription en direct en cours... (Appuyez sur Ctrl+C pour arrêter)")

    try:
        while True:
            with microphone as source:
                audio = recognizer.listen(source)
                try:
                    text = recognizer.recognize_google(audio, language="fr-FR")
                    print("Vous avez dit : " + text)
                except sr.UnknownValueError:
                    print("Audio non compris")
                except sr.RequestError as e:
                    print(f"Erreur lors de la requête ; {e}")
    except KeyboardInterrupt:
        print("Transcription arrêtée.")

if __name__ == "__main__":
    transcribe_live_audio()
# Out:
# Réglage du bruit ambiant...
# Transcription en direct en cours... (Appuyez sur Ctrl+C pour arrêter)
# Transcription arrêtée.

# %%
pip install pyaudio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyaudio
import numpy as np

CHUNK = 1024  # Nombre d'échantillons par bloc
FORMAT = pyaudio.paInt16  # Format du codec audio
CHANNELS = 1  # Nombre de canaux audio (1 pour mono, 2 pour stéréo)
RATE = 44100  # Taux d'échantillonnage (nombre d'échantillons par seconde)

audio = pyaudio.PyAudio()

stream = audio.open(format=FORMAT,
                    channels=CHANNELS,
                    rate=RATE,
                    input=True,
                    frames_per_buffer=CHUNK)

print("Enregistrement audio...")

try:
    while True:
        data = stream.read(CHUNK)
        # Traitement des données audio ici
        # Dans cet exemple, nous affichons les niveaux de volume
        rms = np.sqrt(np.mean(np.square(np.frombuffer(data, dtype=np.int16))))
        print(f"Volume : {rms:.2f}")

except KeyboardInterrupt:
    print("Arrêt de l'enregistrement...")

stream.stop_stream()
stream.close()
audio.terminate()
# Out:
# Enregistrement audio...
# Volume : 0.47
# Volume : 0.49
# Volume : 0.50
# Volume : 0.46
# Volume : 0.47
# Volume : 0.49
# Volume : 0.50
# Volume : 0.46
# Volume : 0.47
# Volume : 0.49
# Volume : 0.50
# Volume : 0.46
# Volume : 0.47
# Volume : 0.49
# Volume : 0.50
# Volume : 0.46
# Volume : 0.47
# Volume : 0.49
# Volume : 0.50
# Volume : 0.46
# Volume : 0.47
# Volume : 0.51
# Volume : 48.81
# Volume : 71.38
# Volume : 59.70
# Volume : 54.69
# Volume : 67.87
# Volume : 65.81
# Volume : 26.95
# Volume : 14.95
# Volume : 71.59
# Volume : 54.67
# Volume : 62.11
# Volume : 35.57
# Volume : 18.76
# Volume : 4.84
# Volume : 9.90
# Volume : 32.36
# Volume : 38.75
# Volume : 8.34
# Volume : 4.87
# Volume : 4.62
# Volume : 20.06
# Volume : 19.98
# Volume : 15.85
# Volume : 6.47
# Volume : 2.45
# Volume : 6.63
# Volume : 6.25
# Volume : 4.27
# Volume : 6.27
# Volume : 6.62
# Volume : 37.64
# Volume : 72.67
# Volume : 80.98
# Volume : 64.27
# Volume : 66.91
# Volume : 57.07
# Volume : 37.71
# ...
